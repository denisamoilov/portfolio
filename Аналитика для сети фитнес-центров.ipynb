# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
# <b>Денис, привет!</b>
#
# Меня зовут Полина Бережная, и я буду делать ревью проекта по машинному обучению. Давай будем общаться на «ты». Но если тебе комфортнее на «вы», обязательно сообщи мне об этом.
#
# Твой проект просто 🔥🔥🔥. Видно, что ты уверенно кодишь и понимаешь базу машинного обучения. Мне было очень приятно читать твои лаконичные и информативные выводы. Твой уровень подачи материала находится на очень высоком уровне. Я не нашла никаких недочетов. Ты умница!
#
# Чтобы ревью было для тебя полезным, я оставила несколько комментариев:
#
# - <div class="alert alert-warning">
#
#   **Комментарий ревьюера**
#
#    Так выделены не обязательные к доработке моменты. Mожешь учесть их при выполнении будущих заданий. На твое усмотрение.
#   </div>
#
#
# - <div class="alert alert-success">
#
#   **Комментарий ревьюера**
#
#     Так отмечены удачные решения и подходы, на которые стоит опираться в будущих проектах.
#   </div>
#
#
# Если будут какие-то вопросы по ревью, обязательно свяжись со мной через куратора или в Slack.
#
# Успехов тебе во всех начинаниях!
#
# </div>

# %% [markdown]
# # Аналитика для сети фитнес-центров «Культурист-датасаентист»с целью разработки стратегии взаимодействия с клиентами на основе аналитических данных

# %% [markdown]
# **Описание проекта**

# %% [markdown]
# **Задача**
#
# Провести анализ и подготовить план действий по удержанию клиентов.
# А именно:
# * научиться прогнозировать вероятность оттока (на уровне следующего месяца) для каждого клиента;
# * сформировать типичные портреты клиентов: выделить несколько наиболее ярких групп и охарактеризовать их основные свойства;
# * проанализировать основные признаки, наиболее сильно влияющие на отток;
# * сформулировать основные выводы и разработать рекомендации по повышению качества работы с клиентами:
#     1) выделить целевые группы клиентов;
#     2) предложить меры по снижению оттока;
#     3) определить другие особенности взаимодействия с клиентами.
#
# **Описание данных**
#
# «Культурист-датасаентист» предоставил сведения в csv-файлах. Заказчик подготовил данные, которые содержат данные на месяц до оттока и факт оттока на определённый месяц. Набор данных включает следующие поля:
# 1. 'Churn' — факт оттока в текущем месяце;
#
#     Текущие поля в датасете:
#     Данные клиента за предыдущий до проверки факта оттока месяц:
#     * 'gender' — пол;
#     * 'Near_Location' — проживание или работа в районе, где находится фитнес-центр;
#     * 'Partner' — сотрудник компании-партнёра клуба (сотрудничество с компаниями, чьи сотрудники могут получать скидки на абонемент — в таком случае фитнес-центр хранит информацию о работодателе клиента);
#     * Promo_friends — факт первоначальной записи в рамках акции «приведи друга» (использовал промо-код от знакомого при оплате первого абонемента);
#     * 'Phone' — наличие контактного телефона;
#     * 'Age' — возраст;
#     * 'Lifetime' — время с момента первого обращения в фитнес-центр (в месяцах).
#
# Информация на основе журнала посещений, покупок и информация о текущем статусе абонемента клиента:
# 2. 'Contract_period' — длительность текущего действующего абонемента (месяц, 3 месяца, 6 месяцев, год);
# 3. 'Month_to_end_contract' — срок до окончания текущего действующего абонемента (в месяцах);
# 4. 'Group_visits' — факт посещения групповых занятий;
# 5. 'Avg_class_frequency_total' — средняя частота посещений в неделю за все время с начала действия абонемента;
# 6. 'Avg_class_frequency_current_month' — средняя частота посещений в неделю за предыдущий месяц;
# 7. 'Avg_additional_charges_total' — суммарная выручка от других услуг фитнес-центра: кафе, спорт-товары, косметический и массажный салон.
#
# **Алгоритм исследования**
# 1. Проведем исследовательский анализ данных (EDA)
# Изучим датасет, узнаем, есть ли в нем отсутствующие признаки, изучим средние значения и стандартные отклонения;
# Изучим средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался;
# Построим столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток);
# Построим матрицу корреляций и отобразим её.
#
#
# 2. Построим модель прогнозирования оттока клиентов
# Построим модель бинарной классификации клиентов, где целевой признак — факт оттока клиента в следующем месяце:
#     * Разобьем данные на обучающую и валидационную выборку функцией train_test_split().
#     * Обучим модель на train-выборке двумя способами: логистической регрессией, случайным лесом.
#     * Оценим метрики accuracy, precision и recall для обеих моделей на валидационной выборке. Определим какая модель показала себя лучше на основании метрик.
#
# 3. Сделаем кластеризацию клиентов
# Отложим в сторону столбец с оттоком и проведите кластеризацию объектов (клиентов):
#     * Стандартизируем данные.
#     * Построим матрицу расстояний функцией linkage() на стандартизованной матрице признаков и нарисуйте дендрограмму. На основании полученного графика предположим, какое количество кластеров можно выделить.
#     * Обучим модель кластеризации на основании алгоритма K-Means и спрогнозируем кластеры клиентов. Договоримся за число кластеров принять n=5, чтобы наши результаты можно было сравнивать с результатами остальных студентов.
#     * Посмотрим на средние значения признаков для кластеров. Построим распределения признаков для кластеров.
#     * Для каждого полученного кластера посчитаем долю оттока. Определим какие кластеры склонны к оттоку, а какие — надёжны.
#
#
# 4. Сформулируем выводы и сделаем базовые рекомендации по работе с клиентами
# Сформулируем основные выводы и предложим рекомендации для стратегии взаимодействия с клиентами и их удержания.

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьювера**
#
# Здорово, что перед кодом есть описание целей проекта, план твоих действий и описание данных 👍🏻. Да и все оформление тетрадки выполнено на достойном уровне. Она рассказывает историю за тебя и показывает как твои кодинговые навыки, так и умение анализировать и преподносить информацию :)

# %% [markdown]
# ##  Загрузим данные

# %% [markdown]
# ### Загрузим необходимые библиотеки

# %%
import pandas as pd
import math as mth
import matplotlib.pyplot as plt
from scipy import stats as st
import numpy as np
import seaborn as sns; sns.set()
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import dendrogram, linkage
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Загрузим датасет и изуим общую информацию

# %%
#сохраним датасет в переменную
data = pd.read_csv('/datasets/gym_churn.csv')

#выведем первые 10 строк и общую информацию
display(data.head(10))
print(data.info())
# Out:
#    gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
# 5       1              1        0              0      1                1
# 6       1              1        1              1      0                6
# 7       0              1        0              0      1                1
# 8       1              1        1              1      1                1
# 9       0              1        0              0      1                1
#
#    Group_visits  Age  Avg_additional_charges_total  Month_to_end_contract  \
# 0             1   29                     14.227470                    5.0
# ...

# %% [markdown]
# В таблице 4000 строк, пропусков не обнаружено, необходимо проверить на наличие дубликатов и привести названия столбцов к нижнему регистру.

# %%
#проверим на наличие дубликатов
print('Кол-во дубликатов в данных: {}\n'.format(data.duplicated().sum()))
# Out:
# Кол-во дубликатов в данных: 0

# %%
#приведем названия столбцов к нижнему регистру
data.columns = data.columns.str.lower()
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
# gender                               4000 non-null int64
# near_location                        4000 non-null int64
# partner                              4000 non-null int64
# promo_friends                        4000 non-null int64
# phone                                4000 non-null int64
# contract_period                      4000 non-null int64
# group_visits                         4000 non-null int64
# age                                  4000 non-null int64
# avg_additional_charges_total         4000 non-null float64
# month_to_end_contract                4000 non-null float64
# lifetime                             4000 non-null int64
# avg_class_frequency_total            4000 non-null float64
# avg_class_frequency_current_month    4000 non-null float64
# churn                                4000 non-null int64
# dtypes: float64(4), int64(10)
# ...

# %% [markdown]
# ### Вывод:

# %% [markdown]
# В представленном наборе данных 4000 строк, дубликатов и пропусков не обнаружено. Названия столбцов приведены к нижнему регистру

# %% [markdown]
# _______________________________________________________________________________________________________________________________

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьювера**
#
# Ты отлично владеешь методами первичного изучения и обработки данных 👍🏻

# %% [markdown]
# ## Проведем исследовательский анализ данных (EDA)

# %% [markdown]
# ### Изучим средние значения и стандартные отклонения

# %%
print('Таблица статистических параметров признаков')
display(data.describe().T)
# Out:
# Таблица статистических параметров признаков
#                                     count        mean        std        min  \
# gender                             4000.0    0.510250   0.499957   0.000000
# near_location                      4000.0    0.845250   0.361711   0.000000
# partner                            4000.0    0.486750   0.499887   0.000000
# promo_friends                      4000.0    0.308500   0.461932   0.000000
# phone                              4000.0    0.903500   0.295313   0.000000
# contract_period                    4000.0    4.681250   4.549706   1.000000
# group_visits                       4000.0    0.412250   0.492301   0.000000
# age                                4000.0   29.184250   3.258367  18.000000
# avg_additional_charges_total       4000.0  146.943728  96.355602   0.148205
# month_to_end_contract              4000.0    4.322750   4.191297   1.000000
# lifetime                           4000.0    3.724750   3.749267   0.000000
# ...

# %% [markdown]
# **Выводы по таблице**
# 1. Пол (gender). Доли полов примерно одинаковы, можно судить о нормальном распределении.
# 2. Близость(near_location). Большинство клиентов (84,5%) находится рядом с фитнес-клубом.
# 3. Партнерство (partner). Около половины клиентов (49,98%) являются сотрудниками партнерских организаций.
# 4. Акция для друзей(promo_friends). Треть клиентов (30,9%) пришли через промо-акцию для друзей (Приведи друга).
# 5. Номер телефона (phone). Известны номера телефонов примерно 90,4% клиентов.
# 6. Продолжительность абонемента (contract_period). Средняя длительность абонементов клиентов - 4.6 месяцев
# 7. Групповые тренировки (group_visits). 41,2% клиентов посещают групповые тренировки.
# 8. Возраст (age). Средний возраст клиентов 29 лет.
# 9. Средние дополнительные расходы (avg_additional_charges_total). Средние дополнительные расходы на клиента - 147
# 10. Количество месяцев до конца срока абонемента (month_to_end_contract). Средний срок до окончания договора - 4.3 месяцев
# 11. Продолжительность пользования услугами (lifetime). Среднее время с момента первого обращения в фитнес-центр - 3.7 месяцев
# 12. Средняя частота посещений за все время (avg_class_frequency_total) - 1.87
# 13. Средняя частота посещений за последний месяц (avg_class_frequency_current_month) - 1.76 раз
# 14. Доля оттока (churn) - 26,5%

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьювера**
#
# Отличный портрет среднестатистического клиента 👍🏻

# %% [markdown]
# <div class="alert alert-warning">
#
# **Комментарий ревьювера**
#
# У переменных довольно разные по величине стандартные отклонения. Это говорит о том, что их нужно стандартизировать перед обучением. Для логистической регрессии и дерева это не обязательно, но вообще это уже такое внегласное правило. Лучше сразу стандартизировать все, а потом уже гонять модели. Стоит указывать на данный нюанс в выводе.

# %% [markdown]
# ### Посмотрим на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался

# %%
#сгруппируем данные по статусу оттока клиента и посчитаем средние значения для признаков
display(data.groupby(['churn']).mean())
# Out:
#          gender  near_location   partner  promo_friends     phone  \
# churn
# 0      0.510037       0.873086  0.534195       0.353522  0.903709
# 1      0.510839       0.768143  0.355325       0.183789  0.902922
#
#        contract_period  group_visits        age  avg_additional_charges_total  \
# churn
# 0             5.747193      0.464103  29.976523                    158.445715
# 1             1.728558      0.268615  26.989632                    115.082899
#
#        month_to_end_contract  lifetime  avg_class_frequency_total  \
# churn
# 0                   5.283089  4.711807                   2.024876
# 1                   1.662582  0.990575                   1.474995
#
#        avg_class_frequency_current_month
# churn
# 0                               2.027882
# 1                               1.044546

# %% [markdown]
# **Вывод по таблице**
#
# Распределение по полу не отличается. Местоположение влияет на отток, чем ближе клиенты, тем реже они попадают в отток.
# Сотрудники компаний-партнеров реже перестают посещать фитнесс-клуб чем остальные клиенты, возможно, это связана с дополнительными привилегиями для партнеров. Клиенты, пришедшие по промо-акции для друзей, в два раза реже уходят в отток. Наличие мобильного номера клиента не влияет на отток. Средняя длительность абонемента больше у оставшихся, возможно, что отток связана с окончанием срока действия договора. У большей части клиентов в оттоке срок договора составляет 1 месяц (это может говорить о том, что чаще клиенты заключают договор на 1 месяц). Оставшиеся пользователи чаще ходят на групповые занятия. У групп есть разница в среднем возрасте клиентов, однако она незначительная, у оставшихся средний возраст 30 лет, в оттоке 27 лет. Есть небольшое различие в выручке от других услуг фитнес-центра, оставшиеся приносят больше денег, но это может быть также связано с продолжительностью пользования услугами. Оставшееся время до окончания срока действия договора больше у оставшихся клиентов, т.е. отток мог быть связан с окончанием абонемента. У клиентов в оттоке меньше среднее количество посещений в неделю за всё время. Количество посещений в предыдущий месяц в два раза ниже у клиентов в оттоке.

# %% [markdown]
# ### Построим столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток)

# %%
#сохраним срезы признаков в отдельные переменные
churn = data[data['churn']==1]
stayed = data[data['churn']==0]

#сохраним список небинарных признаков в переменной
character_list = ['avg_additional_charges_total', 'avg_class_frequency_total', 'avg_class_frequency_current_month', 'lifetime',
             'age', 'contract_period', 'month_to_end_contract']

#построим гистограммы распределения в цикле
for character in character_list:
    plt.figure(figsize=(10,4))
    plt.title(character)
    sns.distplot(churn[character])
    sns.distplot(stayed[character])
    plt.legend(['Отток', 'Оставшиеся'])
    plt.show()

# %%
#построим столбчатые гистограммы для бинарных признаков
for column in data.columns:
    if column not in character_list:
        data.groupby('churn')[column].hist()
        plt.title(column)
        plt.legend(['Оставшиеся', 'Отток'])
        plt.show()

# %% [markdown]
# **Выводы к графикам**
#
# При оценке графиков можно сделать следующие выводы:
# 1. Чем меньше период абонменте, тем выше вероятность, что клиент не вернется;
# 2. Имеет значение возраст клиента, чем он моложе, тем он, скорее всего, уйдет в отток;
# 3. Клиенты, попадающие в отток, меньше пользуются дополнительными платными услугами, но это может быть также связано с длительностью посещения фитнес-клуба.
# 4. Имеет значение близость клиента к фитнес-клубу, чем он ближе, тем выше вероятность, что он останется.
# 5. Имеет значение отношение клиента к партнерской организации;
# 6. Имеет значение промо-акция для друзей. Это может быть связано, в том числе, с тем, что человек приходит в фитнес-клуб не один и не готов его покинуть.
# 7. Имеют значение групповые тренировки, клиенты посещающие их в меньше степени уходят в отток.

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьювера**
#
# Эстетичные визуализации и хороший анализ классов 👍🏻

# %% [markdown]
# ### Построим матрицу корреляций и отобразим её

# %%
plt.figure(figsize=(14,10))
sns.heatmap(data = data.corr(), annot=True, square=True, cmap='YlGnBu')
plt.title('Матрица корреляций', fontsize = 25)
plt.show()

# %% [markdown]
# **Вывод к матрице корреляции**
#
# При оценке матрицы корреляции можно сделать вывод, что существует зависимость между разными парами признаков:
# 1. Принадлежность клиента к партнерской организации коррелирует с промо-акцией для друзей, сроком абонемента и сроком до конца действия абонемента. Однако эта корреляция незначительна. Можно судить о том, что условия для партнеров и в рамках промо-акции более выгодные для клиента и он соглашается на более длительный срок посещения.
# 2. Срок абонемента сильно коррелирует со сроком, оставшимся до конца его действия. Можно судить о наличии мультиколлинеарных признаках.
# В целом, корреляции между другими парами признаком не обнаружено.

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьювера**
#
# Все верно! Одну переменную из пары мультиколлинеарных признаков стоит удалять, иначе она будет доминировать при обучении.

# %% [markdown]
# ### Вывод по разделу

# %% [markdown]
# При изучении средних значений и стандартных отклонений признаков обнаружены следующие закономерности:
# 1. Пол (gender). Доли полов примерно одинаковы, можно судить о нормальном распределении.
# 2. Близость(near_location). Большинство клиентов (84,5%) находится рядом с фитнес-клубом.
# 3. Партнерство (partner). Около половины клиентов (49,98%) являются сотрудниками партнерских организаций.
# 4. Акция для друзей(promo_friends). Треть клиентов (30,9%) пришли через промо-акцию для друзей (Приведи друга).
# 5. Номер телефона (phone). Известны номера телефонов примерно 90,4% клиентов.
# 6. Продолжительность абонемента (contract_period). Средняя длительность абонементов клиентов - 4.6 месяцев
# 7. Групповые тренировки (group_visits). 41,2% клиентов посещают групповые тренировки.
# 8. Возраст (age). Средний возраст клиентов 29 лет.
# 9. Средние дополнительные расходы (avg_additional_charges_total). Средние дополнительные расходы на клиента - 147
# 10. Количество месяцев до конца срока абонемента (month_to_end_contract). Средний срок до окончания договора - 4.3 месяцев
# 11. Продолжительность пользования услугами (lifetime). Среднее время с момента первого обращения в фитнес-центр - 3.7 месяцев
# 12. Средняя частота посещений за все время (avg_class_frequency_total) - 1.87
# 13. Средняя частота посещений за последний месяц (avg_class_frequency_current_month) - 1.76 раз
# 14. Доля оттока (churn) - 26,5%
#
# При оценке средних по признакам по двум группам: тем, кто ушел в отток и кто остался установлено:
# Распределение по полу не отличается. Местоположение влияет на отток, чем ближе клиенты, тем реже они попадают в отток.
# Сотрудники компаний-партнеров реже перестают посещать фитнесс-клуб чем остальные клиенты, возможно, это связана с дополнительными привилегиями для партнеров. Клиенты, пришедшие по промо-акции для друзей, в два раза реже уходят в отток. Наличие мобильного номера клиента не влияет на отток. Средняя длительность абонемента больше у оставшихся, возможно, что отток связана с окончанием срока действия договора. У большей части клиентов в оттоке срок договора составляет 1 месяц (это может говорить о том, что чаще клиенты заключают договор на 1 месяц). Оставшиеся пользователи чаще ходят на групповые занятия. У групп есть разница в среднем возрасте клиентов, однако она незначительная, у оставшихся средний возраст 30 лет, в оттоке 27 лет. Есть небольшое различие в выручке от других услуг фитнес-центра, оставшиеся приносят больше денег, но это может быть также связано с продолжительностью пользования услугами. Оставшееся время до окончания срока действия договора больше у оставшихся клиентов, т.е. отток мог быть связан с окончанием абонемента. У клиентов в оттоке меньше среднее количество посещений в неделю за всё время. Количество посещений в предыдущий месяц в два раза ниже у клиентов в оттоке.
#
# По итогам интерпретации столбчатых гисттограмм и гистограмм распределения по признакам можно сделать следующие выводы:
# 1. Чем меньше период абонменте, тем выше вероятность, что клиент не вернется;
# 2. Имеет значение возраст клиента, чем он моложе, тем он, скорее всего, уйдет в отток;
# 3. Клиенты, попадающие в отток, меньше пользуются дополнительными платными услугами, но это может быть также связано с длительностью посещения фитнес-клуба.
# 4. Имеет значение близость клиента к фитнес-клубу, чем он ближе, тем выше вероятность, что он останется.
# 5. Имеет значение отношение клиента к партнерской организации;
# 6. Имеет значение промо-акция для друзей. Это может быть связано, в том числе, с тем, что человек приходит в фитнес-клуб не один и не готов его покинуть.
# 7. Имеют значение групповые тренировки, клиенты посещающие их в меньше степени уходят в отток.
#
# При оценке матрицы корреляции можно сделать вывод, что существует зависимость между разными парами признаков:
# 1. Принадлежность клиента к партнерской организации коррелирует с промо-акцией для друзей, сроком абонемента и сроком до конца действия абонемента. Однако эта корреляция незначительна. Можно судить о том, что условия для партнеров и в рамках промо-акции более выгодные для клиента и он соглашается на более длительный срок посещения.
# 2. Срок абонемента сильно коррелирует со сроком, оставшимся до конца его действия. Можно судить о наличии мультиколлинеарных признаках.
# В целом, корреляции между другими парами признаком не обнаружено.

# %% [markdown]
# _______________________________________________________________________________________________________________________________

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьювера**
#
# Здорово, что исследование было резюмировано 👍🏻
#
# Но стоит избегать полного дублировани промежуточных выводов.

# %% [markdown]
# ## Построим модель прогнозирования оттока клиентов

# %% [markdown]
# **Построим модель бинарной классификации клиентов, где целевой признак — факт оттока клиента в следующем месяце**

# %% [markdown]
# ### Разобьем данные на обучающую и валидационную выборку функцией train_test_split()

# %% [markdown]
# <div class="alert alert-warning">
#
# **Комментарий ревьюера**
#
# Можно использовать параметр stratify = y в функции train_test_split( ), где y – соответствующая целевая переменная. Данные разделятся на два кластера (наблюдения класса 0 и наблюдения класса 1), и в валидационную выборку попадут по 20% наблюдений из каждого кластера:
#
# ![image.png](attachment:image.png)
# То есть, если соотношение классов в оригинальной выборке было 2:5, то в обучающей и валидационной выборках оно сохранится таким же. Такой подход в чем-то решает проблему несбалансированных классов.
#
# Функция train_test_split( ) строена так, что мы не сталкиваемся с подобной проблемой. Но я все же пишу про этот параметр, чтобы обратить внимание на проблему дисбаланса :)</div>

# %%
X = data.drop(['churn'], axis = 1)
y = data['churn']
#разобьем выборки в соотношении 80 на 20 %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ### Обучим модель на train-выборке двумя способами: логистической регрессией и случайным лесом

# %%
#нормализуем выборки
scaler = StandardScaler()
X_train_st = scaler.fit_transform(X_train)
X_test_st = scaler.transform(X_test)

#обучим модель логистической регрессией
lr_model = LogisticRegression(random_state=0)
lr_model.fit(X_train_st, y_train)
lr_predictions = lr_model.predict(X_test_st)
lr_probabilities = lr_model.predict_proba(X_test_st)[:,1]

#обучим модель случайным лесом
rf_model = RandomForestClassifier(n_estimators = 100, random_state = 0) 
rf_model.fit(X_train_st, y_train)
rf_predictions = rf_model.predict(X_test_st)
rf_probabilities = rf_model.predict_proba(X_test_st)[:,1]

# %% [markdown]
# ### Оценим метрики accuracy, precision и recall для обеих моделей на валидационной выборке. Сравним по ним модели. Определим, какая модель показала себя лучше на основании метрик.

# %%
#выведем метрики для логистической регрессии, протестируем на валидационной выборке
print('Метрики для логистической регрессии:')
print('accuracy_score: {}\nprecision_score: {}\nrecall_score:{}'.format(
    accuracy_score(y_test, lr_predictions),
    precision_score(y_test, lr_predictions),
    recall_score(y_test, lr_predictions)
))

#выведем метрики для случайного леса, протестируем на валидационной выборке
print('\nМетрики для случайного леса:')
print('accuracy_score: {}\nprecision_score: {}\nrecall_score:{}'.format(
    accuracy_score(y_test, rf_predictions),
    precision_score(y_test, rf_predictions),
    recall_score(y_test, rf_predictions)
))
# Out:
# Метрики для логистической регрессии:
# accuracy_score: 0.9225
# precision_score: 0.8541666666666666
# recall_score:0.8282828282828283
#
# Метрики для случайного леса:
# accuracy_score: 0.915
# precision_score: 0.8385416666666666
# recall_score:0.8131313131313131

# %% [markdown]
# ### Вывод по разделу

# %% [markdown]
# При сравнении моделей установлено, что доля правильных прогнозов и полнота выше в модели логистической регрессии, но незначительно. Можно сделать вывод, что модель логистической регрессии показала себя лучше на основании метрик.

# %% [markdown]
# _______________________________________________________________________________________________________________________________

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьювера**
#
# Этап выполнен абсолютно корректно! Молодец :)

# %% [markdown]
# ## Сделаем кластеризацию клиентов

# %% [markdown]
# ### Стандартизируем данные

# %%
X_st = scaler.fit_transform(X)

# %% [markdown]
# ### Построим матрицу расстояний функцией linkage() на стандартизованной матрице признаков и нарисуем дендрограмму

# %%
linked = linkage(X_st, method='ward')
plt.figure(figsize=(15, 10))
dendrogram(linked, orientation='top')
plt.title('\n Иерархическая кластеризация', fontsize=15)
plt.show()

# %% [markdown]
# **Вывод по дендрограмме**
#
# По дендрограмме можно выделить 4 кластера. Однако, будем следовать заданию и договоримся за число кластеров принять n=5, чтобы  результаты можно было сравнивать с результатами остальных студентов.

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьювера**
#
#  👍🏻

# %% [markdown]
# ### Обучим модель кластеризации на основании алгоритма K-Means и спрогнозируйте кластеры клиентов

# %%
km = KMeans(n_clusters = 5, random_state = 0)
labels = km.fit_predict(X_st)
data['cluster_km'] = labels
data_clusters = data.groupby('cluster_km').mean()
display(data_clusters)
# Out:
#               gender  near_location   partner  promo_friends     phone  \
# cluster_km
# 0           0.502473       0.959446  0.783383       0.574679  1.000000
# 1           0.522078       0.862338  0.470130       0.306494  0.000000
# 2           0.495050       0.000000  0.463366       0.079208  1.000000
# 3           0.485737       1.000000  0.350238       0.240095  1.000000
# 4           0.560335       0.976105  0.356033       0.229391  0.998805
#
#             contract_period  group_visits        age  \
# cluster_km
# 0                 10.884273      0.543027  29.980218
# 1                  4.787013      0.425974  29.301299
# 2                  2.352475      0.215842  28.477228
# 3                  1.948494      0.341521  28.167987
# 4                  2.665472      0.473118  30.127838
#
#             avg_additional_charges_total  month_to_end_contract  lifetime  \
# cluster_km
# 0                             160.706969               9.950544  4.738872
# ...

# %% [markdown]
# ### Для каждого полученного кластера посчитайте долю оттока

# %%
print('Доля оттока по кластерам')
display((data_clusters['churn'] *100).round(1).astype(str) + '%')
# Out:
# Доля оттока по кластерам
# cluster_km
# 0     2.8%
# 1    26.8%
# 2    44.4%
# 3    51.4%
# 4     6.8%
# Name: churn, dtype: object

# %% [markdown]
# ### Построим распределения признаков для кластеров

# %%
for value in [0, 1, 2, 3, 4]:
    data[data['cluster_km']==value].hist(figsize=(17,10))
    plt.suptitle('\nРаспределение признаков для кластера {}'.format(value), fontsize = 15)
    plt.show()

# %% [markdown]
# <div class="alert alert-warning">
#
# **Комментарий ревьювера**
#
# Для дискретных переменных можно также построить обычные столбчатые диаграммы на одном графике, а для непрерывных – боксплоты (это позволит избежать наложения распределений друг на друга). Например:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Посмотрим на средние значения признаков для кластеров (вывод к таблице с кластерами и гистограммам распределения)

# %% [markdown]
# 1. Кластер 0
#
# Отток - 2.7% - самый низкий среди всех кластеров. Живут или работают недалеко от фитнес-центра. Преобладают сотрудники или клиенты партнеров - 78,3%. Покупают абонементы на длительный срок - до 12 месяцев. Чаще других посещают групповые занятия - 54,3%. Больше других кластеров пришли по промо-акции для друзей.
#
# 2. Кластер 1
#
# Отток в кластере - 26%. Живут или работают недалеко от фитнес-центра. Единственный клстер, у клиентов которого нет мобильного номера в распоряжении фитнес-клуба. Абонементы до 4-5 месяцев.
#
# 3. Кластер 2
#
# Отток - 44%. Клиенты кластера неходятся далеко от фитнес-клуба. Реже всех посещают групповые занятия.
#
# 4. Кластер 3
#
# Отток составляет 51,4% - самый высокий среди всех кластеров. Местоположение самое близкое к фитнес-центру. Являются обладателями недолгосрочных абонементов до 2-3 месяцев. Наименьшее кол-во посещений за всё время и в последний месяц. Меньше всего являются клиентами или сотрудниками партнеров. Средний возраст 28 лет.
#
# 5. Кластер 4
#
# Отток - 6,8%. Живут или работают недалеко от фитнес-центра. Чаще всех посещают клуб - 2.81 раз в неделю. Абонементы недолгосрочные, до 3 месяцев.
#
# Вывод: наиболее надежны клиенты из 3 кластера, за ними идут клиенты из 2 кластера

# %% [markdown]
# ### Вывод по разделу

# %% [markdown]
# Провели кластеризацию клиентов. По дендрограмме можно выделить 4 кластера. Однако, будем следовать заданию и договоримся за число кластеров 5.
#
# Проанализировав средние значения по признакам и построив гистограмму распределения можно сделать следующие выводы по кластерам:
#
# Кластер 0
# Отток - 2.7% - самый низкий среди всех кластеров. Живут или работают недалеко от фитнес-центра. Преобладают сотрудники или клиенты партнеров - 78,3%. Покупают абонементы на длительный срок - до 12 месяцев. Чаще других посещают групповые занятия - 54,3%. Больше других кластеров пришли по промо-акции для друзей.
#
# Кластер 1
# Отток в кластере - 26%. Живут или работают недалеко от фитнес-центра. Единственный клстер, у клиентов которого нет мобильного номера в распоряжении фитнес-клуба. Абонементы до 4-5 месяцев.
#
# Кластер 2
# Отток - 44%. Клиенты кластера неходятся далеко от фитнес-клуба. Реже всех посещают групповые занятия.
#
# Кластер 3
# Отток составляет 51,4% - самый высокий среди всех кластеров. Местоположение самое близкое к фитнес-центру. Являются обладателями недолгосрочных абонементов до 2-3 месяцев. Наименьшее кол-во посещений за всё время и в последний месяц. Меньше всего являются клиентами или сотрудниками партнеров. Средний возраст 28 лет.
#
# Кластер 4
# Отток - 6,8%. Живут или работают недалеко от фитнес-центра. Чаще всех посещают клуб - 2.81 раз в неделю. Абонементы недолгосрочные, до 3 месяцев.
#
# Вывод: наиболее надежны клиенты из 3 кластера, за ними идут клиенты из 2 кластера

# %% [markdown]
# _______________________________________________________________________________________________________________________________

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьювера**
#
# В целом, были подобраны правильные визуализации, проведен качественный анализ и предоставлены лаконичные и информативные выводы! Супер 👍🏻

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Сформулируем основные выводы по результатам анализа и предложим рекомендации для стратегии взаимодействия с пользователями и их удержания. В нашем распоряжении были данные по клиентам фитнес-клуба, всего 4000 строк.  Мы построили прогнозную модель. Теперь мы можем прогнозировать вероятность оттока по каждому клиенту.
#
# При изучении средних значений и стандартных отклонений признаков обнаружены следующие закономерности:
# 1. Пол (gender). Доли полов примерно одинаковы, можно судить о нормальном распределении.
# 2. Близость(near_location). Большинство клиентов (84,5%) находится рядом с фитнес-клубом.
# 3. Партнерство (partner). Около половины клиентов (49,98%) являются сотрудниками партнерских организаций.
# 4. Акция для друзей(promo_friends). Треть клиентов (30,9%) пришли через промо-акцию для друзей (Приведи друга).
# 5. Номер телефона (phone). Известны номера телефонов примерно 90,4% клиентов.
# 6. Продолжительность абонемента (contract_period). Средняя длительность абонементов клиентов - 4.6 месяцев
# 7. Групповые тренировки (group_visits). 41,2% клиентов посещают групповые тренировки.
# 8. Возраст (age). Средний возраст клиентов 29 лет.
# 9. Средние дополнительные расходы (avg_additional_charges_total). Средние дополнительные расходы на клиента - 147
# 10. Количество месяцев до конца срока абонемента (month_to_end_contract). Средний срок до окончания договора - 4.3 месяцев
# 11. Продолжительность пользования услугами (lifetime). Среднее время с момента первого обращения в фитнес-центр - 3.7 месяцев
# 12. Средняя частота посещений за все время (avg_class_frequency_total) - 1.87
# 13. Средняя частота посещений за последний месяц (avg_class_frequency_current_month) - 1.76 раз
# 14. Доля оттока (churn) - 26,5%
#
# При оценке средних по признакам по двум группам: тем, кто ушел в отток и кто остался установлено:
# Распределение по полу не отличается. Местоположение влияет на отток, чем ближе клиенты, тем реже они попадают в отток.
# Сотрудники компаний-партнеров реже перестают посещать фитнесс-клуб чем остальные клиенты, возможно, это связана с дополнительными привилегиями для партнеров. Клиенты, пришедшие по промо-акции для друзей, в два раза реже уходят в отток. Наличие мобильного номера клиента не влияет на отток. Средняя длительность абонемента больше у оставшихся, возможно, что отток связана с окончанием срока действия договора. У большей части клиентов в оттоке срок договора составляет 1 месяц (это может говорить о том, что чаще клиенты заключают договор на 1 месяц). Оставшиеся пользователи чаще ходят на групповые занятия. У групп есть разница в среднем возрасте клиентов, однако она незначительная, у оставшихся средний возраст 30 лет, в оттоке 27 лет. Есть небольшое различие в выручке от других услуг фитнес-центра, оставшиеся приносят больше денег, но это может быть также связано с продолжительностью пользования услугами. Оставшееся время до окончания срока действия договора больше у оставшихся клиентов, т.е. отток мог быть связан с окончанием абонемента. У клиентов в оттоке меньше среднее количество посещений в неделю за всё время. Количество посещений в предыдущий месяц в два раза ниже у клиентов в оттоке.
#
# По итогам интерпретации столбчатых гисттограмм и гистограмм распределения по признакам можно сделать следующие выводы:
# 1. Чем меньше период абонменте, тем выше вероятность, что клиент не вернется;
# 2. Имеет значение возраст клиента, чем он моложе, тем он, скорее всего, уйдет в отток;
# 3. Клиенты, попадающие в отток, меньше пользуются дополнительными платными услугами, но это может быть также связано с длительностью посещения фитнес-клуба.
# 4. Имеет значение близость клиента к фитнес-клубу, чем он ближе, тем выше вероятность, что он останется.
# 5. Имеет значение отношение клиента к партнерской организации;
# 6. Имеет значение промо-акция для друзей. Это может быть связано, в том числе, с тем, что человек приходит в фитнес-клуб не один и не готов его покинуть.
# 7. Имеют значение групповые тренировки, клиенты посещающие их в меньше степени уходят в отток.
#
# При оценке матрицы корреляции можно сделать вывод, что существует зависимость между разными парами признаков:
# 1. Принадлежность клиента к партнерской организации коррелирует с промо-акцией для друзей, сроком абонемента и сроком до конца действия абонемента. Однако эта корреляция незначительна. Можно судить о том, что условия для партнеров и в рамках промо-акции более выгодные для клиента и он соглашается на более длительный срок посещения.
# 2. Срок абонемента сильно коррелирует со сроком, оставшимся до конца его действия. Можно судить о наличии мультиколлинеарных признаках.
# В целом, корреляции между другими парами признаком не обнаружено.
#
# Построили и обучили две модели по логистической регрессии и случаному лесу. При сравнении моделей установлено, что доля правильных прогнозов и полнота выше в модели логистической регрессии, но незначительно. Можно сделать вывод, что модель логистической регрессии показала себя лучше на основании метрик.
#
# Провели кластеризацию клиентов. По дендрограмме можно выделить 4 кластера. Однако, будем следовать заданию и договоримся за число кластеров 5.
#
# Проанализировав средние значения по признакам и построив гистограмму распределения можно сделать следующие выводы по кластерам:
#
# Кластер 0 Отток - 2.7% - самый низкий среди всех кластеров. Живут или работают недалеко от фитнес-центра. Преобладают сотрудники или клиенты партнеров - 78,3%. Покупают абонементы на длительный срок - до 12 месяцев. Чаще других посещают групповые занятия - 54,3%. Больше других кластеров пришли по промо-акции для друзей.
#
# Кластер 1 Отток в кластере - 26%. Живут или работают недалеко от фитнес-центра. Единственный клстер, у клиентов которого нет мобильного номера в распоряжении фитнес-клуба. Абонементы до 4-5 месяцев.
#
# Кластер 2 Отток - 44%. Клиенты кластера неходятся далеко от фитнес-клуба. Реже всех посещают групповые занятия.
#
# Кластер 3 Отток составляет 51,4% - самый высокий среди всех кластеров. Местоположение самое близкое к фитнес-центру. Являются обладателями недолгосрочных абонементов до 2-3 месяцев. Наименьшее кол-во посещений за всё время и в последний месяц. Меньше всего являются клиентами или сотрудниками партнеров. Средний возраст 28 лет.
#
# Кластер 4 Отток - 6,8%. Живут или работают недалеко от фитнес-центра. Чаще всех посещают клуб - 2.81 раз в неделю. Абонементы недолгосрочные, до 3 месяцев.
#
# Вывод: наиболее надежны клиенты из 3 кластера, за ними идут клиенты из 2 кластера
#
# **Рекомендации**:
#
# Выгоднее продавать долгосрочные абонементы от 3 месяцев. Необходимо развивать программы для клиентов - сотрудников партнерских организаций и ориентироваться на клиентов и близлежащих районов фитнес-центра. Также можно использовать промо-акцию для друзей, так как можно сделать вывод о ее эффективности. Необходимо обеспечивать доступ к групповым тренировкам, так как они обеспечивают "лояльность" клиентов. Основной возраст, на который стоит ориентироваться: от 28 до 30 лет.

# %% [markdown]
# <div class="alert alert-success">
#
# **Комментарий ревьювера**
#
# Предложены интересные идеи по удержанию  🔥
#
# Было бы здорово предложить какие-то идеи определенных маркетинговых действий.
